# %%
import pandas as pd
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import seaborn as sns


#file_path = 'spotify_10_songs.csv'
df_songs = pd.read_csv('spotify_10_songs.csv')#, index_col='artist')

#print(df_songs.columns)
#df_songs.info()
df_songs.columns = df_songs.columns.str.strip()
df_songs['song_name'] = df_songs['song_name'].str.rstrip(' .')
df_songs.set_index('song_name', inplace=True)
to_drop = ['artist', 'html', 'id', 'time_signature', 'duration_ms', 'mode','key']
df_songs = df_songs.drop(columns=to_drop)

# %%
sorted_songs = df_songs.sort_values(by='danceability', ascending=False)
sorted_songs
# Out:
#                                                     danceability   energy  \
# song_name
# The Real Slim Shady                                        0.949  0.66100
# My Band                                                    0.851  0.84900
# Space Raiders - Charlotte de Witte Remix                   0.749  0.73100
# In Silence                                                 0.736  0.84500
# Sultans Of Swing                                           0.733  0.79400
# Águas De Março                                             0.642  0.33900
# The Girl From Ipanema                                      0.641  0.14000
# Paint It, Black                                            0.464  0.79500
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...         0.387  0.04510
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...         0.184  0.00833
#
#                                                     loudness  speechiness  \
# song_name
# The Real Slim Shady                                   -4.244       0.0572
# My Band                                               -3.383       0.0828
# Space Raiders - Charlotte de Witte Remix             -10.865       0.1080
# In Silence                                           -12.017       0.0377
# Sultans Of Swing                                     -10.023       0.0307
# Águas De Março                                       -15.503       0.1400
# The Girl From Ipanema                                -16.790       0.0390
# Paint It, Black                                       -9.267       0.0926
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...   -24.698       0.0364
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...   -33.503       0.0519
#
#                                                     acousticness  \
# song_name
# The Real Slim Shady                                      0.03020
# My Band                                                  0.49700
# Space Raiders - Charlotte de Witte Remix                 0.00314
# In Silence                                               0.00548
# Sultans Of Swing                                         0.06140
# Águas De Março                                           0.85400
# The Girl From Ipanema                                    0.86700
# Paint It, Black                                          0.04930
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...       0.99000
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...       0.98900
#
#                                                     instrumentalness  \
# song_name
# The Real Slim Shady                                         0.000000
# My Band                                                     0.000002
# Space Raiders - Charlotte de Witte Remix                    0.867000
# In Silence                                                  0.901000
# Sultans Of Swing                                            0.036700
# Águas De Março                                              0.000000
# The Girl From Ipanema                                       0.001660
# Paint It, Black                                             0.002440
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...          0.913000
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...          0.596000
#
#                                                     liveness  valence  \
# song_name
# The Real Slim Shady                                   0.0454   0.7600
# My Band                                               0.1160   0.8440
# Space Raiders - Charlotte de Witte Remix              0.1110   0.0598
# In Silence                                            0.1110   0.1980
# Sultans Of Swing                                      0.3300   0.9310
# Águas De Março                                        0.1050   0.4910
# The Girl From Ipanema                                 0.1050   0.3880
# Paint It, Black                                       0.3990   0.6120
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...    0.1120   0.0710
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...    0.1040   0.2110
#
#                                                       tempo  table
# song_name
# The Real Slim Shady                                 104.504      3
# My Band                                             120.014      5
# Space Raiders - Charlotte de Witte Remix            131.997      0
# In Silence                                          128.009      0
# Sultans Of Swing                                    148.174      4
# Águas De Março                                      143.418      4
# The Girl From Ipanema                               129.318      0
# Paint It, Black                                     158.691      2
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...   61.494      1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...   61.541      1

# %%
# Calculate the Euclidean distances between all pairs of students in the foods_df DataFrame
distances_array = pairwise_distances(df_songs, metric='euclidean')

# Create a Pandas DataFrame from the distances_array
euclidean_distances_df = pd.DataFrame(distances_array,
                                      index=df_songs.index,
                                      columns=df_songs.index,)

# Display the Euclidean distances DataFrame
euclidean_distances_df
# Out:
# song_name                                             My Band  \
# song_name
# My Band                                              0.000000
# The Real Slim Shady                                 15.542746
# Águas De Março                                      26.366662
# The Girl From Ipanema                               16.346428
# Paint It, Black                                     39.128237
# Sultans Of Swing                                    28.936816
# Space Raiders - Charlotte de Witte Remix            14.184786
# In Silence                                          11.830130
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...                                           8.814374
#
# song_name                                           Nocturne en mi bémol majeur opus 9 n°2: Ballade en Sol Mineur No.1
# song_name
# My Band                                                                                     62.301344
# The Real Slim Shady                                                                         47.656645
# Águas De Março                                                                              82.445621
# The Girl From Ipanema                                                                       68.290930
# Paint It, Black                                                                             98.427807
# Sultans Of Swing                                                                            87.931086
# Space Raiders - Charlotte de Witte Remix                                                    71.858247
# In Silence                                                                                  67.725920
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...                                           8.814374
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...                                           0.000000

# %%
# Create a figure with a size of 12 inches by 8 inches
plt.subplots(figsize=(8, 6))

# Generate a heatmap of the Euclidean distances DataFrame
sns.heatmap(euclidean_distances_df);

# %%
# 1. import the model
from sklearn.cluster import KMeans

# 2. initialize the model
random_seed = 654567
my_kmeans = KMeans(n_clusters = 6, # we'll explore how to choose the number of clusters in a later notebook
                   random_state = random_seed,
                   n_init='auto'
                   )

# 3. fit the model to the data
my_kmeans.fit(df_songs)

# 4. obtain the cluster output
table = my_kmeans.labels_

# 5. attach the cluster output to our original DataFrame
df_songs["table"] = table

df_songs.sort_values(by="table")
# Out:
#                                                     danceability   energy  \
# song_name
# My Band                                                    0.851  0.84900
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...         0.184  0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...         0.387  0.04510
# Águas De Março                                             0.642  0.33900
# Sultans Of Swing                                           0.733  0.79400
# The Girl From Ipanema                                      0.641  0.14000
# Space Raiders - Charlotte de Witte Remix                   0.749  0.73100
# In Silence                                                 0.736  0.84500
# The Real Slim Shady                                        0.949  0.66100
# Paint It, Black                                            0.464  0.79500
#
#                                                     loudness  speechiness  \
# song_name
# My Band                                               -3.383       0.0828
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...   -33.503       0.0519
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...   -24.698       0.0364
# Águas De Março                                       -15.503       0.1400
# Sultans Of Swing                                     -10.023       0.0307
# The Girl From Ipanema                                -16.790       0.0390
# Space Raiders - Charlotte de Witte Remix             -10.865       0.1080
# In Silence                                           -12.017       0.0377
# The Real Slim Shady                                   -4.244       0.0572
# Paint It, Black                                       -9.267       0.0926
#
#                                                     acousticness  \
# song_name
# My Band                                                  0.49700
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...       0.98900
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...       0.99000
# Águas De Março                                           0.85400
# Sultans Of Swing                                         0.06140
# The Girl From Ipanema                                    0.86700
# Space Raiders - Charlotte de Witte Remix                 0.00314
# In Silence                                               0.00548
# The Real Slim Shady                                      0.03020
# Paint It, Black                                          0.04930
#
#                                                     instrumentalness  \
# song_name
# My Band                                                     0.000002
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...          0.596000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...          0.913000
# Águas De Março                                              0.000000
# Sultans Of Swing                                            0.036700
# The Girl From Ipanema                                       0.001660
# Space Raiders - Charlotte de Witte Remix                    0.867000
# In Silence                                                  0.901000
# The Real Slim Shady                                         0.000000
# Paint It, Black                                             0.002440
#
#                                                     liveness  valence  \
# song_name
# My Band                                               0.1160   0.8440
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...    0.1040   0.2110
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...    0.1120   0.0710
# Águas De Março                                        0.1050   0.4910
# Sultans Of Swing                                      0.3300   0.9310
# The Girl From Ipanema                                 0.1050   0.3880
# Space Raiders - Charlotte de Witte Remix              0.1110   0.0598
# In Silence                                            0.1110   0.1980
# The Real Slim Shady                                   0.0454   0.7600
# Paint It, Black                                       0.3990   0.6120
#
#                                                       tempo  table
# song_name
# My Band                                             120.014      0
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...   61.541      1
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...   61.494      1
# Águas De Março                                      143.418      2
# Sultans Of Swing                                    148.174      2
# The Girl From Ipanema                               129.318      3
# Space Raiders - Charlotte de Witte Remix            131.997      3
# In Silence                                          128.009      3
# The Real Slim Shady                                 104.504      4
# Paint It, Black                                     158.691      5
